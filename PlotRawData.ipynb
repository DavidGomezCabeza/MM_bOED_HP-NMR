# %% [markdown]
# # Load Packages

# %%
using DifferentialEquations
using OrdinaryDiffEq
using DiffEqBase
using Sundials
using ODEInterfaceDiffEq
using Plots
using Measures
using CSV
using DataFrames
# using Turing
# using MCMCChains
using EasyFit
using StatsPlots
using LinearAlgebra
using Random
using Distributions
using OrdinaryDiffEq
using LsqFit
using BlackBoxOptim
using LaTeXStrings

# %%
using XLSX

# %% [markdown]
# # Plot 2 Million

# %%
Dat1 = Matrix(CSV.read("C:\\IBECPostDocDrive\\2024_01_16_NCvsKR\\Paper\\RawData\\2Million_Rep1_HepG2_16_01_2024.csv", DataFrame));
Dat2 = Matrix(CSV.read("C:\\IBECPostDocDrive\\2024_01_16_NCvsKR\\Paper\\RawData\\2Million_Rep2_HepG2_05_02_2024.csv", DataFrame));
Dat3 = Matrix(CSV.read("C:\\IBECPostDocDrive\\2024_01_16_NCvsKR\\Paper\\RawData\\2Million_Rep3_HepG2_08_03_2024.csv", DataFrame));


pp1 = scatter(Dat1[:,1], Dat1[:,2], label = "Dat1", xlabel = "Time (sec)", ylabel = "Pyruvate (A.U.)")
scatter!(Dat2[:,1], Dat2[:,2], label = "Dat2")
scatter!(Dat3[:,1], Dat3[:,2], label = "Dat3")

pp2 = scatter(Dat1[:,1], Dat1[:,3], label = "Dat1", xlabel = "Time (sec)", ylabel = "Lactate (A.U.)")
scatter!(Dat2[:,1], Dat2[:,3], label = "Dat2")
scatter!(Dat3[:,1], Dat3[:,3], label = "Dat3")

plot(pp1,pp2, size = (1600,700), margin = 8mm, title = "2 Million")

# %% [markdown]
# # Plot 4 Million

# %%
Dat1 = Matrix(CSV.read("C:\\IBECPostDocDrive\\2024_01_16_NCvsKR\\Paper\\RawData\\4Million_Rep1_HepG2_16_01_2024.csv", DataFrame));
Dat2 = Matrix(CSV.read("C:\\IBECPostDocDrive\\2024_01_16_NCvsKR\\Paper\\RawData\\4Million_Rep2_HepG2_29_01_2024.csv", DataFrame));
Dat3 = Matrix(CSV.read("C:\\IBECPostDocDrive\\2024_01_16_NCvsKR\\Paper\\RawData\\4Million_Rep3_HepG2_24_05_2024.csv", DataFrame));


pp1 = scatter(Dat1[:,1], Dat1[:,2], label = "Dat1", xlabel = "Time (sec)", ylabel = "Pyruvate (A.U.)")
scatter!(Dat2[:,1], Dat2[:,2], label = "Dat2")
scatter!(Dat3[:,1], Dat3[:,2], label = "Dat3")

pp2 = scatter(Dat1[:,1], Dat1[:,3], label = "Dat1", xlabel = "Time (sec)", ylabel = "Lactate (A.U.)")
scatter!(Dat2[:,1], Dat2[:,3], label = "Dat2")
scatter!(Dat3[:,1], Dat3[:,3], label = "Dat3")

plot(pp1,pp2, size = (1600,700), margin = 8mm, title = "4 Million")

# %%
Dat4 = Matrix(CSV.read("C:\\IBECPostDocDrive\\2024_01_16_NCvsKR\\Paper\\RawData\\4Million_LysateNADH184uM_Rep1_HepG2_28_05_2024.csv", DataFrame));
Dat5 = Matrix(CSV.read("C:\\IBECPostDocDrive\\2024_01_16_NCvsKR\\Paper\\RawData\\4Million_LysateNADH184uM_Rep2_HepG2_05_06_2024.csv", DataFrame));

# %%
pp3 = scatter(Dat1[3:50,1], mean([Dat1[3:50,3],Dat2[3:50,3],Dat3[3:50,3]])./maximum(mean([Dat1[3:50,3],Dat2[3:50,3],Dat3[3:50,3]])) , label = "Alive", xlabel = "Time (sec)", ylabel = "Lactate (A.U.)", size = (1000,700), margin = 8mm)
scatter!(Dat1[3:50,1], Dat4[3:50,3]./maximum(Dat4[3:50,3]) , label = "Lysate", xlabel = "Time (sec)", ylabel = "Lactate (A.U.)")
# scatter!(Dat1[3:50,1], zz[3:50]./maximum(zz))
scatter!(Dat1[3:50,1], Dat5[3:50,3]./maximum(Dat5[3:50,3]) , label = "Lysate", xlabel = "Time (sec)", ylabel = "Lactate (A.U.)")

# %% [markdown]
# # Plot 8 Million

# %%
Dat1 = Matrix(CSV.read("C:\\IBECPostDocDrive\\2024_01_16_NCvsKR\\Paper\\RawData\\8Million_Rep1_HepG2_16_01_2024.csv", DataFrame));
Dat2 = Matrix(CSV.read("C:\\IBECPostDocDrive\\2024_01_16_NCvsKR\\Paper\\RawData\\8Million_Rep2_HepG2_01_03_2024.csv", DataFrame));
Dat3 = Matrix(CSV.read("C:\\IBECPostDocDrive\\2024_01_16_NCvsKR\\Paper\\RawData\\8Million_Rep3_HepG2_04_03_2024.csv", DataFrame));


pp1 = scatter(Dat1[:,1], Dat1[:,2], label = "Dat1", xlabel = "Time (sec)", ylabel = "Pyruvate (A.U.)")
scatter!(Dat2[:,1], Dat2[:,2], label = "Dat2")
scatter!(Dat3[:,1], Dat3[:,2], label = "Dat3")

pp2 = scatter(Dat1[:,1], Dat1[:,3], label = "Dat1", xlabel = "Time (sec)", ylabel = "Lactate (A.U.)")
scatter!(Dat2[:,1], Dat2[:,3], label = "Dat2")
scatter!(Dat3[:,1], Dat3[:,3], label = "Dat3")

plot(pp1,pp2, size = (1600,700), margin = 8mm, title = "8 Million")

# %% [markdown]
# # Plot 8 Million No CO2

# %%
Dat1 = Matrix(CSV.read("C:\\IBECPostDocDrive\\2024_01_16_NCvsKR\\Paper\\RawData\\8Million_NoCO2_Rep1_Try3_HepG2_07_03_2024.csv", DataFrame));
Dat2 = Matrix(CSV.read("C:\\IBECPostDocDrive\\2024_01_16_NCvsKR\\Paper\\RawData\\8Million_NoCO2_Rep2_Try1_HepG2_07_03_2024.csv", DataFrame));
# Dat3 = Matrix(CSV.read("C:\\IBECPostDocDrive\\2024_01_16_NCvsKR\\Paper\\RawData\\8Million_Rep3_HepG2_04_03_2024.csv", DataFrame));


pp1 = scatter(Dat1[:,1], Dat1[:,2], label = "Dat1", xlabel = "Time (sec)", ylabel = "Pyruvate (A.U.)")
scatter!(Dat2[:,1], Dat2[:,2], label = "Dat2")
# scatter!(Dat3[:,1], Dat3[:,2], label = "Dat3")

pp2 = scatter(Dat1[:,1], Dat1[:,3], label = "Dat1", xlabel = "Time (sec)", ylabel = "Lactate (A.U.)")
scatter!(Dat2[:,1], Dat2[:,3], label = "Dat2")
# scatter!(Dat3[:,1], Dat3[:,3], label = "Dat3")

plot(pp1,pp2, size = (1600,700), margin = 8mm, title = "8 Million No CO2")

# %% [markdown]
# # Plot Lysed 4 Million Cells

# %%
Dat1 = Matrix(CSV.read("C:\\IBECPostDocDrive\\2024_01_16_NCvsKR\\Paper\\RawData\\4Million_LysateNADH184uM_Rep1_HepG2_28_05_2024.csv", DataFrame));
Dat2 = Matrix(CSV.read("C:\\IBECPostDocDrive\\2024_01_16_NCvsKR\\Paper\\RawData\\4Million_LysateNADH184uM_Rep2_HepG2_07_06_2024_Try1.csv", DataFrame));
Dat3 = Matrix(CSV.read("C:\\IBECPostDocDrive\\2024_01_16_NCvsKR\\Paper\\RawData\\4Million_LysateNADH184uM_Rep3_HepG2_07_06_2024_Try2.csv", DataFrame));


pp1 = scatter(Dat1[:,1], Dat1[:,2], label = "Dat1", xlabel = "Time (sec)", ylabel = "Pyruvate (A.U.)")
scatter!(Dat2[:,1], Dat2[:,2], label = "Dat2")
scatter!(Dat3[:,1], Dat3[:,2], label = "Dat3")

pp2 = scatter(Dat1[:,1], Dat1[:,3], label = "Dat1", xlabel = "Time (sec)", ylabel = "Lactate (A.U.)")
scatter!(Dat2[:,1], Dat2[:,3], label = "Dat2")
scatter!(Dat3[:,1], Dat3[:,3], label = "Dat3")

plot(pp1,pp2, size = (1600,700), margin = 8mm, title = "4 Million Lysed")

# %% [markdown]
# # Plot 3 Million, 3.2mM

# %%
Dat1 = Matrix(CSV.read("C:\\IBECPostDocDrive\\2024_01_16_NCvsKR\\Paper\\RawData_DiffPyr\\3.2Pyr_2025_02_05_DGC_HepG2_3Mil_3.2mMPyruvate_NewTryControl.csv", DataFrame));
Dat2 = Matrix(CSV.read("C:\\IBECPostDocDrive\\2024_01_16_NCvsKR\\Paper\\RawData_DiffPyr\\3.2Pyr_2025_02_05_DGC_HepG2_3Mil_3.2mMPyruvate_NewTryControl2.csv", DataFrame));
Dat3 = Matrix(CSV.read("C:\\IBECPostDocDrive\\2024_01_16_NCvsKR\\Paper\\RawData_DiffPyr\\3.2Pyr_2025_02_14_DGC_HepG2_3Mil_3.2mMPyruvate_NewTryControl1.csv", DataFrame));


pp1 = scatter(Dat1[:,1], Dat1[:,2], label = "Dat1", xlabel = "Time (sec)", ylabel = "Pyruvate (A.U.)")
scatter!(Dat2[:,1], Dat2[:,2], label = "Dat2")
scatter!(Dat3[:,1], Dat3[:,2], label = "Dat3")

pp2 = scatter(Dat1[:,1], Dat1[:,3], label = "Dat1", xlabel = "Time (sec)", ylabel = "Lactate (A.U.)")
scatter!(Dat2[:,1], Dat2[:,3], label = "Dat2")
scatter!(Dat3[:,1], Dat3[:,3], label = "Dat3")

plot(pp1,pp2, size = (1600,700), margin = 8mm, title = "3 Million, 3.2 mM")
